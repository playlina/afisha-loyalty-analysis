# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Екатерина, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# В этом проекте мы разбираемся, от чего зависит возврат пользователей на сервис «Яндекс Афиша». Нам важно понять, какие характеристики первого заказа, поведение пользователей и особенности их покупок могут влиять на решение вернуться и сделать повторный заказ.
#
# **Цель проекта:**
# выявить факторы, которые связаны с повторными покупками пользователей, и по итогам предложить рекомендации по удержанию аудитории.
#
# **Основные задачи:**
# - собрать и подготовить данные о заказах пользователей;
# - привести выручку к единой валюте и очистить данные от выбросов;
# - построить профиль каждого пользователя и рассмотреть ключевые метрики;
# - исследовать признаки первого заказа и их связь с возвратами;
# - изучить влияние среднего чека, количества билетов и временных характеристик на повторные покупки;
# - проверить продуктовые гипотезы статистическими методами;
# - выполнить корреляционный анализ факторов, связанных с числом заказов;
# - сформулировать выводы и рекомендации для заказчика.

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# - **Хост** — `rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net`
# - **База данных** — `data-analyst-afisha`
# - **Порт** — `6432`
# - **Аутентификация** — `Database Native`
# - **Пользователь** — `praktikum_student`
# - **Пароль** — `Sdf4$2;d-d30pp`
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %%
# !pip install phik
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 40.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from dotenv import load_dotenv
import os
from statsmodels.stats.proportion import proportions_ztest
from phik.report import plot_correlation_matrix

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %%
load_dotenv()

DB_USER = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')


connection_string = (
    f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}?sslmode=require')
engine = create_engine(connection_string)
query = """SELECT 1;"""  # для теста
test_df = pd.read_sql(query, con=engine)
print(test_df)
# Out:
#    ?column?
# 0         1

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали, коннектор сделали - отлично!

# %%
sql = """
SELECT table_schema, table_name
FROM information_schema.tables
WHERE table_schema NOT IN ('information_schema', 'pg_catalog')
ORDER BY table_schema, table_name;
"""
tables = pd.read_sql(sql, con=engine)
display(tables)
# Out:
#   table_schema      table_name
# 0       afisha            city
# 1       afisha          events
# 2       afisha       purchases
# 3       afisha         regions
# 4       afisha          venues
# 5       public  financial_data
# 6       public   prolongations
# 7       public    temp_devices

# %%
sql_columns = """
SELECT
    column_name, data_type
FROM information_schema.columns
WHERE table_schema = 'afisha'
  AND table_name = 'purchases'
ORDER BY column_name;
"""

cols = pd.read_sql(sql_columns, con=engine)
cols
# Out:
#               column_name                    data_type
# 0               age_limit                      integer
# 1          cinema_circuit            character varying
# 2          created_dt_msk  timestamp without time zone
# 3          created_ts_msk  timestamp without time zone
# 4           currency_code            character varying
# 5   device_type_canonical            character varying
# 6                event_id                      integer
# 7                order_id                      integer
# 8                 revenue                         real
# 9            service_name            character varying
# 10          tickets_count                      integer
# 11                  total                         real
# 12                user_id            character varying

# %%
sql = """
WITH base AS (
    SELECT
        p.*,
        e.*,
        c.*,
        r.*,
        LAG(p.created_ts_msk) OVER (
            PARTITION BY p.user_id
            ORDER BY p.created_ts_msk
        ) AS prev_created_ts_msk
    FROM afisha.purchases p
    LEFT JOIN afisha.events  e ON p.event_id = e.event_id
    LEFT JOIN afisha.city    c ON e.city_id = c.city_id
    LEFT JOIN afisha.regions r ON c.region_id = r.region_id
)
SELECT
    base.*,
    (base.created_ts_msk::date - base.prev_created_ts_msk::date) AS days_since_prev
FROM base;
"""

df = pd.read_sql(sql, con=engine)
df.head()
# Out:
#    order_id          user_id created_dt_msk      created_ts_msk  event_id  \
# 0   4359165  0002849b70a3ce2     2024-08-20 2024-08-20 16:08:03    169230
# 1   7965605  0005ca5e93f2cf4     2024-07-23 2024-07-23 18:36:24    237325
# 2   7292370  0005ca5e93f2cf4     2024-10-06 2024-10-06 13:56:02    578454
# 3   1139875  000898990054619     2024-07-13 2024-07-13 19:40:48    387271
# 4    972400  000898990054619     2024-10-04 2024-10-04 22:33:15    509453
#
#   cinema_circuit  age_limit currency_code device_type_canonical  revenue  ...  \
# 0            нет         16           rub                mobile  1521.94  ...
# 1            нет          0           rub                mobile   289.45  ...
# 2            нет          0           rub                mobile  1258.57  ...
# 3            нет          0           rub                mobile     8.49  ...
# 4            нет         18           rub                mobile  1390.41  ...
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные из запроса получены.

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
# размер датасета (число строк и столбцов)
print(df.shape)

# информация о типах данных и пропусках
df.info()

# быстрый просмотр первых строк
df.head()

# описание числовых столбцов
df.describe()

# доля пропусков по каждому столбцу
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# (292034, 27)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292034 entries, 0 to 292033
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                292034 non-null  int64
#  1   user_id                 292034 non-null  object
#  2   created_dt_msk          292034 non-null  datetime64[ns]
#  3   created_ts_msk          292034 non-null  datetime64[ns]
#  4   event_id                292034 non-null  int64
#  5   cinema_circuit          292034 non-null  object
#  6   age_limit               292034 non-null  int64
#  7   currency_code           292034 non-null  object
#  8   device_type_canonical   292034 non-null  object
#  9   revenue                 292034 non-null  float64
#  10  service_name            292034 non-null  object
#  11  tickets_count           292034 non-null  int64
#  12  total                   292034 non-null  float64
# ...

# %% [markdown]
# В итоговой выгрузке получилось 292 034 строки и 27 столбцов. Базовые данные выглядят аккуратно: по основным полям (идентификаторы заказов и пользователей, дата и время покупки, тип устройства, выручка, количество билетов, характеристики события, город и регион) пропусков нет — все значения заполнены. Форматы тоже адекватные: даты хранятся в формате datetime, числовые признаки — в числовых типах, текст — в строках. Это даёт хорошую основу для дальнейшего анализа: не нужно дополнительно чистить базовые поля или восстанавливать критичные значения.
#
# Отдельно появились два новых поля — prev_created_ts_msk и days_since_prev, которые рассчитываются как лаг по предыдущей покупке пользователя и разница в днях между покупками. В них около 7,5 % пропусков — это ожидаемая ситуация для первых покупок пользователя, когда «предыдущей» даты просто нет. Также видно, что после джойнов некоторые идентификаторы дублируются (event_id, city_id, region_id встречаются по два раза). На этапе подготовки данных для анализа эти дубли лучше оставить в одном экземпляре, чтобы не плодить лишние столбцы и не создавать путаницу при дальнейших расчётах и визуализациях.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные и пропуски изучены, намечены шаги по их обработке.

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %%
url = "https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv"
tenge_rates = pd.read_csv(url)
print(tenge_rates.head())
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %%
tenge_rates = tenge_rates.rename(columns={'data': 'date', 'curs': 'tenge_rub'})
tenge_rates['date'] = pd.to_datetime(tenge_rates['date']).dt.date
df['date'] = pd.to_datetime(df['created_dt_msk']).dt.date

# %%
df = df.merge(tenge_rates[['date', 'tenge_rub']], on='date', how='left')

# %%
def to_rub(row):
    if row['currency_code'] == 'KZT':
        return row['revenue'] * row['tenge_rub'] / 100
    else:
        return row['revenue']
df['revenue_rub'] = df.apply(to_rub, axis=1)
df['revenue_rub']
# Out:
# 0         1521.94
# 1          289.45
# 2         1258.57
# 3            8.49
# 4         1390.41
#            ...
# 292029     965.57
# 292030     965.57
# 292031     178.95
# 292032     661.53
# 292033     802.25
# Name: revenue_rub, Length: 292034, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выручка приведена к единой валюте.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Решение с `.apply` неэффективное, так как оно применяет функцию к каждой строке таблицы поочерёдно - это может быть затратно на больших таблицах. Лучше использовать маски:
#
# ```python
# # Создаем Series (словарь) из курсов: 'data' -> 'curs'
# # Это нужно сделать один раз, а не на каждой строке.
# rate_map = exchange_rates.set_index('data')['curs']
#
# # Используем .map() для "подтягивания" курса в df по дате 'order_dt'
# # Это C-оптимизированная операция, во много раз быстрее apply
# df['rate'] = df['order_dt'].map(rate_map)
#
# # Инициализируем новую колонку значением по умолчанию
# df['revenue_rub'] = df['revenue']
#
# # Создаем маску (условие) для строк, которые нужно конвертировать
# mask = df['currency_code'] == 'kzt'
#
# # Выполняем векторизированную операцию ТОЛЬКО для нужных строк
# df.loc[mask, 'revenue_rub'] = df['revenue'] * df['rate'] / 100
# ```

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %%
columns_to_keep = [
    'order_id', 'user_id', 'created_dt_msk', 'event_id', 'event_name_code',
    'event_type_main', 'event_type_description', 'tickets_count',
    'revenue', 'revenue_rub', 'device_type_canonical', 'service_name',
    'city_name', 'region_name', 'currency_code', 'days_since_prev']
df = df[columns_to_keep]

# %%
na_counts = df.isnull().sum().sort_values(ascending=False)
na_percent = (df.isnull().mean() * 100).sort_values(ascending=False)
display(pd.DataFrame({'count': na_counts, 'percent': na_percent}))
# Out:
#                         count   percent
# days_since_prev         22000  7.533369
# order_id                    0  0.000000
# user_id                     0  0.000000
# event_id                    0  0.000000
# created_dt_msk              0  0.000000
# event_name_code             0  0.000000
# event_type_main             0  0.000000
# event_type_description      0  0.000000
# event_id                    0  0.000000
# tickets_count               0  0.000000
# revenue                     0  0.000000
# device_type_canonical       0  0.000000
# revenue_rub                 0  0.000000
# service_name                0  0.000000
# city_name                   0  0.000000
# region_name                 0  0.000000
# currency_code               0  0.000000

# %%
dup_cols = df.columns[df.columns.duplicated()]
print('Дублирующиеся столбцы:', list(dup_cols))
if len(dup_cols) > 0:
    df = df.loc[:, ~df.columns.duplicated()]
# Out:
# Дублирующиеся столбцы: ['event_id']

# %%
df = df.loc[:, ~df.columns.duplicated()]

# %%
full_dups = df.duplicated().sum()
order_dups = df.duplicated(subset='order_id').sum()
print(f'Полных дубликатов строк: {full_dups}')
print(f'Дубликатов по order_id: {order_dups}')
# Out:
# Полных дубликатов строк: 0
# Дубликатов по order_id: 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Прежде чем удалять дубликаты, нужно проверить их наличие. Удалять дубликаты, если их нет, нет смысла. Стоит также проверить явные дубликаты и дубликаты по `order_id`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Подскажи, ты на уровне данных видишь дублирование столбца `event_id`? Если его нет, почему оно показано в коде?
#
# Также не проверены дубликаты - общие и по `order_id`.

# %%
cat_cols = [
    'device_type_canonical', 'currency_code', 'service_name',
    'event_type_main', 'city_name', 'region_name']
for col in cat_cols:
    if col in df.columns:
        df[col] = df[col].astype('category')

if 'created_dt_msk' in df.columns:
    df['created_dt_msk'] = pd.to_datetime(df['created_dt_msk'])
int_cols = df.select_dtypes(include=['int64']).columns
df[int_cols] = df[int_cols].astype('int32')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292034 entries, 0 to 292033
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                292034 non-null  int32
#  1   user_id                 292034 non-null  object
#  2   created_dt_msk          292034 non-null  datetime64[ns]
#  3   event_id                292034 non-null  int32
#  4   event_name_code         292034 non-null  object
#  5   event_type_main         292034 non-null  category
#  6   event_type_description  292034 non-null  object
#  7   tickets_count           292034 non-null  int32
#  8   revenue                 292034 non-null  float64
#  9   revenue_rub             292034 non-null  float64
#  10  device_type_canonical   292034 non-null  category
#  11  service_name            292034 non-null  category
#  12  city_name               292034 non-null  category
# ...

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента v.2  <a class="tocSkip"> </h2>
#
# Исправлено. Дубликатов нет
# </div>

# %% [markdown]
# Типы данных приведены к оптимальным: категориальные признаки переведены в category, даты — в datetime, числовые значения — в int32 и float64. Пропуски присутствуют только в столбце days_since_prev, что объясняется его логикой (отсутствие предыдущей покупки у части пользователей). Данных с пропусками или техническими категориями в других полях не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Типы данных оптимизированы.

# %% [markdown]
# Проверка уникальных категорий и подозрительных значений

# %%
for col in cat_cols:
    print(f"\n{col}: {df[col].unique()}")
    print(df[col].value_counts())
# Out:
# device_type_canonical: ['mobile', 'desktop', 'tablet', 'other', 'tv']
# Categories (5, object): ['desktop', 'mobile', 'other', 'tablet', 'tv']
# device_type_canonical
# mobile     232679
# desktop     58170
# tablet       1180
# tv              3
# other           2
# Name: count, dtype: int64
#
# currency_code: ['rub', 'kzt']
# Categories (2, object): ['kzt', 'rub']
# currency_code
# rub    286961
# kzt      5073
# Name: count, dtype: int64
#
# service_name: ['Край билетов', 'Мой билет', 'За билетом!', 'Лови билет!', 'Билеты без проблем', ..., 'Цвет и билет', 'Зе Бест!', 'Тех билет', 'Лимоны', 'Билеты в интернете']
# Length: 36
# Categories (36, object): ['Crazy ticket!', 'Show_ticket', 'Билет по телефону', 'Билеты без проблем',
#                           ..., 'Тех билет', 'Цвет и билет', 'Шоу начинается!', 'Яблоко']
# service_name
# Билеты без проблем        63932
# Лови билет!               41338
# Билеты в руки             40500
# Мой билет                 34965
# ...

# %% [markdown]
# В категориальных столбцах (device_type_canonical, currency_code, service_name, event_type_main, city_name, region_name) данные выглядят логично и осмысленно. Большая часть заказов оформляется с мобильных устройств (≈232,7 тыс. строк), на втором месте — desktop (≈58,2 тыс.), доля заказов с планшетов и тем более с ТВ и «other» уже заметно меньше и выглядит как естественный «хвост» редких сценариев. По валютам ожидаемо доминирует российский рубль (286 961 заказ), казахстанский тенге используется значительно реже (5 073 заказа), что тоже вписывается в здравый смысл.
#
# Распределение по service_name показывает нормальную картину рынка: есть несколько ярко выраженных лидеров по числу заказов — «Билеты без проблем», «Лови билет!», «Билеты в руки», «Мой билет», «Облачко», за ними — длинный хвост из менее крупных партнёров. По типам событий (event_type_main) тоже всё выглядит реалистично: больше всего заказов приходится на концерты и театр, заметная доля у категории «другое» и спорта, стендап и выставки занимают меньшую, но понятную долю, «ёлки» и фильмы ожидаемо встречаются реже.
#
# По городам и регионам (city_name, region_name) картина напоминает типичное распределение: есть несколько крупных центров с максимальным числом заказов (например, Глиногорск, Озёрск, Каменевский регион, Североярская область), а дальше идёт длинный хвост из менее крупных территорий с постепенно уменьшающимися объёмами. «Мусорных» либо технических значений, вроде странных кодов или пустых строк, в категориальных полях не выявлено.
#
# В целом категориальные признаки уже находятся в хорошем состоянии: значения осмысленные, распределения реалистичные, аномалий нет. Дополнительной нормализации на этом этапе не требуется — признаки можно сразу использовать в дальнейшем анализе и сегментации.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Категориальные признаки проверены на предмет аномалий.

# %%
print(df[['revenue_rub', 'tickets_count']].describe())
# Out:
#          revenue_rub  tickets_count
# count  292034.000000  292034.000000
# mean      624.833773       2.754508
# std      1225.695694       1.170305
# min       -90.760000       1.000000
# 25%       116.790000       2.000000
# 50%       355.340000       3.000000
# 75%       809.460000       4.000000
# max     81174.540000      57.000000

# %% [markdown]
# Средняя выручка заказа — около 625 ₽, при этом медиана заметно ниже — примерно 355 ₽. Это говорит о том, что распределение сильно скошено вправо: есть небольшое число крупных заказов, которые тянут среднее вверх. Это подтверждается и максимумом — почти 81 175 ₽ за заказ, что явно похоже на групповую покупку большого числа билетов или корпоративное бронирование.
#
# Количество билетов в заказе в среднем составляет 2,75, медиана — 3 билета, а межквартильный размах лежит между 2 и 4 билетами. То есть типичный заказ — это 2–4 билета, что логично для похода небольшой компанией или семьёй. При этом встречаются экстремальные случаи до 57 билетов в одном заказе — снова похоже на групповые или корпоративные покупки.
#
# Отдельно стоит отметить минимальное значение выручки — −90,76 ₽. Отрицательная выручка, скорее всего, связана с возвратами, перерасчётами или компенсациями, а не с ошибкой в данных. Таких случаев немного, но их нужно учитывать при анализе: в зависимости от цели исследования их можно либо оставить, как есть, либо вынести в отдельный слой аналитики по возвратам и корректировкам.

# %%
neg_revenue = df[df['revenue_rub'] < 0]
print(neg_revenue)

print(f"Число заказов с отрицательной выручкой: {neg_revenue.shape[0]}")
# Out:
#         order_id          user_id created_dt_msk  event_id  \
# 264      1594653  00eb3dc9baa1543     2024-06-29    538650
# 4564     2360920  02ea4583333f064     2024-09-03    559772
# 4577     2361094  02ea4583333f064     2024-09-04    559772
# 8188      166780  043f669c9f734b1     2024-09-27    567183
# 8189      166809  043f669c9f734b1     2024-09-27    567183
# ...          ...              ...            ...       ...
# 290249   3700575  fe237d2cfd6e503     2024-10-12    247058
# 290352   3523617  fe237d2cfd6e503     2024-10-15    243963
# 290353   3523646  fe237d2cfd6e503     2024-10-15    243963
# 290480   5445853  fe237d2cfd6e503     2024-10-21    243393
# 291481   5114789  ff20aac2834373f     2024-10-24    575628
#
#                              event_name_code event_type_main  \
# 264     ffe03bc6-0e0c-480d-b037-6a4b55540ab5          другое
# 4564    592856bb-09a5-4d32-9534-0e02c6056e44          другое
# 4577    592856bb-09a5-4d32-9534-0e02c6056e44          другое
# ...

# %%
neg_revenue[['order_id', 'user_id', 'created_dt_msk', 'revenue', 'revenue_rub', 'currency_code', 'service_name']]
# Out:
#         order_id          user_id created_dt_msk  revenue  revenue_rub  \
# 264      1594653  00eb3dc9baa1543     2024-06-29    -2.37        -2.37
# 4564     2360920  02ea4583333f064     2024-09-03    -0.23        -0.23
# 4577     2361094  02ea4583333f064     2024-09-04    -0.15        -0.15
# 8188      166780  043f669c9f734b1     2024-09-27    -1.86        -1.86
# 8189      166809  043f669c9f734b1     2024-09-27    -0.62        -0.62
# ...          ...              ...            ...      ...          ...
# 290249   3700575  fe237d2cfd6e503     2024-10-12    -5.70        -5.70
# 290352   3523617  fe237d2cfd6e503     2024-10-15    -0.96        -0.96
# 290353   3523646  fe237d2cfd6e503     2024-10-15    -1.43        -1.43
# 290480   5445853  fe237d2cfd6e503     2024-10-21    -0.61        -0.61
# 291481   5114789  ff20aac2834373f     2024-10-24    -0.23        -0.23
#
#        currency_code        service_name
# 264              rub  Билеты без проблем
# ...

# %% [markdown]
# Всего таких заказов 381 из 292 034, то есть примерно 0,13 % выборки. Во всех случаях tickets_count остаётся положительным, а вот revenue и revenue_rub принимают небольшие отрицательные значения — чаще всего от нуля до нескольких рублей, реже — более крупные суммы. Все операции идут в рублях, и распределены они по нескольким крупным билетным сервисам: в выборку попадают «Билеты без проблем», «Лучшие билеты», «Тебе билет!» и др. По времени такие заказы встречаются в разные дни и у разных пользователей, иногда плотными группами с days_since_prev = 0, что похоже на корректировки сразу после исходной покупки.
#
# По смыслу это очень похоже на возвраты, перерасчёты или технические корректировки (например, отмена части билетов, перерасчёт комиссии, скидка задним числом). Можно убрать их из данных.

# %%
total_before = df.shape[0]

# %%
df = df[df['revenue_rub'] >= 0]

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['revenue_rub'], bins=100, kde=True)
plt.title('Распределение выручки (revenue_rub)')
plt.subplot(1,2,2)
sns.histplot(df['tickets_count'], bins=20, kde=False)
plt.title('Распределение количества билетов (tickets_count)')
plt.show()

# %% [markdown]
# Распределение сильно скошено вправо: подавляющее большинство заказов — на небольшие суммы (от 0 до 1000 ₽).
# Очень малое число заказов с крупными чеками (типичные выбросы).

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x=df['revenue_rub'])
plt.title('Диаграмма размаха выручки')
plt.show()

# %% [markdown]
# Большинство заказов укладываются в диапазон до 2000 ₽, но есть выбросы: отдельные заказы на суммы 5000 ₽, 12 500 ₽, 17 000 ₽ и выше.
# Видны редкие точки сильно выше основного диапазона — это либо крупные корпоративные покупки, либо ошибки в данных (их обычно фильтруют по 99‑му перцентилю).

# %%
rub_99 = df['revenue_rub'].quantile(0.99)
initial_count = df.shape[0]
df = df[df['revenue_rub'] <= rub_99]
filtered_count = df.shape[0]
print(f"Отфильтровано {initial_count - filtered_count} заказов ({(initial_count-filtered_count)/initial_count:.1%} от всех)")
# Out:
# Отфильтровано 2913 заказов (1.0% от всех)

# %%
plt.figure(figsize=(10,4))
sns.histplot(df['revenue_rub'], bins=50, kde=True)
plt.title('Распределение выручки (после фильтрации выбросов)')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Численные признаки изучены, удалены выбросы.

# %%
filtered_count = df.shape[0]

percent_left = filtered_count / total_before * 100
percent_left
# Out:
# 98.87204914496257

# %% [markdown]
# С учётом фильтрации по отрицательной выручке и по 99-му перцентилю в датасете осталось около 98,9 % заказов, то есть обработка затронула лишь ~1,1 % строк. Объём данных практически не изменился, поэтому дальнейшие выводы можно считать устойчивыми, а выбросы и технические корректировки — аккуратно вынесенными за скобки анализа.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не выполнена заключительная часть обработки данных:
#
#     После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
df = df.sort_values(['user_id', 'created_dt_msk'])

# %%
user_profile = df.groupby('user_id').agg(
    first_order_dt=('created_dt_msk', 'min'),
    last_order_dt=('created_dt_msk', 'max'),
    first_device=('device_type_canonical', 'first'),
    first_region=('region_name', 'first'),
    first_service=('service_name', 'first'),
    first_event_type=('event_type_main', 'first'),
    total_orders=('order_id', 'count'),
    avg_revenue_rub=('revenue_rub', 'mean'),
    avg_tickets=('tickets_count', 'mean'),
    avg_days_between_orders=('days_since_prev', lambda x: np.mean(x))).reset_index()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Вместо `np.mean` можно использовать `mean`.

# %%
user_profile
# Out:
#                user_id first_order_dt last_order_dt first_device  \
# 0      0002849b70a3ce2     2024-08-20    2024-08-20       mobile
# 1      0005ca5e93f2cf4     2024-07-23    2024-10-06       mobile
# 2      000898990054619     2024-07-13    2024-10-23       mobile
# 3      00096d1f542ab2b     2024-08-15    2024-08-15      desktop
# 4      000a55a418c128c     2024-09-29    2024-10-15       mobile
# ...                ...            ...           ...          ...
# 21816  fff13b79bd47d7c     2024-07-16    2024-10-31       mobile
# 21817  fff32fc9ad0f9f6     2024-08-15    2024-10-28      desktop
# 21818  fffcd3dde79eb2c     2024-06-20    2024-10-30      desktop
# 21819  fffeeb3c120cf0b     2024-09-24    2024-09-24      desktop
# 21820  ffff00725179321     2024-09-25    2024-09-25       mobile
#
#                first_region       first_service first_event_type  \
# 0        Каменевский регион        Край билетов            театр
# ...

# %%
user_profile['is_two'] = (user_profile['total_orders'] >= 2).astype(int)
user_profile['is_five'] = (user_profile['total_orders'] >= 5).astype(int)

# %%
user_profile
# Out:
#                user_id first_order_dt last_order_dt first_device  \
# 0      0002849b70a3ce2     2024-08-20    2024-08-20       mobile
# 1      0005ca5e93f2cf4     2024-07-23    2024-10-06       mobile
# 2      000898990054619     2024-07-13    2024-10-23       mobile
# 3      00096d1f542ab2b     2024-08-15    2024-08-15      desktop
# 4      000a55a418c128c     2024-09-29    2024-10-15       mobile
# ...                ...            ...           ...          ...
# 21816  fff13b79bd47d7c     2024-07-16    2024-10-31       mobile
# 21817  fff32fc9ad0f9f6     2024-08-15    2024-10-28      desktop
# 21818  fffcd3dde79eb2c     2024-06-20    2024-10-30      desktop
# 21819  fffeeb3c120cf0b     2024-09-24    2024-09-24      desktop
# 21820  ffff00725179321     2024-09-25    2024-09-25       mobile
#
#                first_region       first_service first_event_type  \
# 0        Каменевский регион        Край билетов            театр
# ...

# %% [markdown]
# Для каждого пользователя построен профиль, отражающий основные особенности его поведения: даты первого и последнего заказа, данные о первом заказе (устройство, регион, сервис, жанр мероприятия), агрегированные метрики (количество заказов, средние показатели по чекам и билетам, средний интервал между покупками), а также признаки возвратности (флаги 2+ и 5+ заказов)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Профиль пользователя собран, бинарные признаки добавлены.

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
n_users = user_profile.shape[0]
avg_revenue_per_order = user_profile['avg_revenue_rub'].mean()
share_2plus = user_profile['is_two'].mean()
share_5plus = user_profile['is_five'].mean()

print(f'Число пользователей: {n_users}')
print(f'Средняя выручка с заказа: {avg_revenue_per_order:.2f} ₽')
print(f'Доля пользователей с 2+ заказами: {share_2plus:.2%}')
print(f'Доля пользователей с 5+ заказами: {share_5plus:.2%}')
# Out:
# Число пользователей: 21821
# Средняя выручка с заказа: 574.45 ₽
# Доля пользователей с 2+ заказами: 61.79%
# Доля пользователей с 5+ заказами: 29.07%

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Общие статистики по профилю посчитаны.

# %%
print(user_profile['total_orders'].describe())
print(user_profile['avg_tickets'].describe())
print(user_profile['avg_days_between_orders'].describe())
# Out:
# count    21821.000000
# mean        13.232208
# std        122.495024
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10256.000000
# Name: total_orders, dtype: float64
# count    21821.000000
# mean         2.748974
# std          0.921211
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.111111
# max         11.000000
# Name: avg_tickets, dtype: float64
# count    13532.000000
# mean        15.956893
# std         22.439057
# min          0.000000
# 25%          1.000000
# 50%          8.114379
# 75%         20.600000
# max        148.000000
# Name: avg_days_between_orders, dtype: float64

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 4))
user_profile['total_orders'].hist(ax=axs[0], bins=20)
axs[0].set_title('Общее число заказов')
user_profile['avg_tickets'].hist(ax=axs[1], bins=10)
axs[1].set_title('Среднее число билетов')
user_profile['avg_days_between_orders'].hist(ax=axs[2], bins=20)
axs[2].set_title('Среднее время между заказами')
plt.show()

# %% [markdown]
# В выборке 21 676 пользователей. Средняя выручка с одного заказа — около 541,9 ₽. При этом 61,7 % пользователей сделали как минимум два заказа, а почти 29 % — пять и более. То есть база не «одноразовая»: у сервиса заметная доля лояльных и регулярно возвращающихся клиентов, на которых имеет смысл строить дальнейший анализ поведения и монетизации.
#
# По общему числу заказов на пользователя распределение сильно неравномерное. Медиана — 2 заказа, 75-й перцентиль — 5 заказов, но среднее значение «улетает» до 13 заказов за счёт хвоста. Максимум — более 10 тысяч заказов на одного user_id. Это явно выбросы: такие профили больше похожи на корпоративные/служебные аккаунты или технические записи, а не на обычных клиентов. Их немного, но они сильно искажают средние значения. Для описательной аналитики я бы их оставила в данных, но отдельно отмечала, что все средние показатели по заказам чувствительны к этому хвосту. Если дальше будет задача строить модели или сегментацию, логично обрезать распределение по верхнему перцентилю (например, 99-му) и считать метрики уже на «нормальной» части пользователей.
#
# Среднее число билетов в заказе — около 2,7, медиана — примерно 2,75, а основная масса значений лежит в диапазоне 2–4 билета. Максимум — 11 билетов в среднем на заказ для отдельных пользователей. Это выглядит реалистично: кто-то ходит один или вдвоём, кто-то стабильно покупает билеты на небольшие компании. Явных аномалий по этому показателю нет, фильтрация здесь не требуется.
#
# Интервалы между покупками (avg_days_between_orders) посчитаны только для тех, у кого больше одного заказа. Медиана — около 8 дней, среднее — около 16 дней, что говорит о том, что многие пользователи возвращаются довольно быстро, но есть и длинные паузы. Значения от 0 дней (несколько заказов в один день) до 100+ дней выглядят логично для реального поведения: часть аудитории покупает билеты «сериями», часть — время от времени. Отдельных грубых аномалий здесь тоже нет, обрезать распределение по интервалам между покупками необходимости нет.

# %%
orders_99 = user_profile['total_orders'].quantile(0.99)
tickets_99 = user_profile['avg_tickets'].quantile(0.99)

print(f"99-й перцентиль total_orders: {orders_99}")
print(f"99-й перцентиль avg_tickets: {tickets_99}")

orders_outliers = user_profile[user_profile['total_orders'] > orders_99].shape[0]
tickets_outliers = user_profile[user_profile['avg_tickets'] > tickets_99].shape[0]
print(f"Пользователей с total_orders выше 99-го перцентиля: {orders_outliers}")
print(f"Пользователей с avg_tickets выше 99-го перцентиля: {tickets_outliers}")
# Out:
# 99-й перцентиль total_orders: 151.0
# 99-й перцентиль avg_tickets: 5.0
# Пользователей с total_orders выше 99-го перцентиля: 218
# Пользователей с avg_tickets выше 99-го перцентиля: 206

# %%
filtered_profile = user_profile[
    (user_profile['total_orders'] <= orders_99) &
    (user_profile['avg_tickets'] <= tickets_99)]
filtered_out = user_profile.shape[0] - filtered_profile.shape[0]
print(f"Отфильтровано аномальных профилей: {filtered_out} из {user_profile.shape[0]}")
# Out:
# Отфильтровано аномальных профилей: 424 из 21821

# %%
print(filtered_profile['total_orders'].describe())
print(filtered_profile['avg_tickets'].describe())
print(filtered_profile['avg_days_between_orders'].describe())
# Out:
# count    21397.000000
# mean         6.546619
# std         14.354850
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        151.000000
# Name: total_orders, dtype: float64
# count    21397.000000
# mean         2.717899
# std          0.870824
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.076923
# max          5.000000
# Name: avg_tickets, dtype: float64
# count    13245.000000
# mean        16.262759
# std         22.547949
# min          0.000000
# 25%          1.433962
# 50%          8.500000
# 75%         21.000000
# max        148.000000
# Name: avg_days_between_orders, dtype: float64

# %% [markdown]
# По сумме можно сказать, что данных достаточно по объёму и они репрезентативны для анализа поведения пользователей. Единственный ярко выраженный источник аномалий — небольшая группа «суперактивных» пользователей с тысячами заказов; их стоит явно учитывать в интерпретации метрик и при необходимости обрабатывать отдельно (ограничивать верхний хвост при расчётах или выносить в отдельный сегмент).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выбросы по профилю пользователю удалены.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
genre_counts = user_profile['first_event_type'].value_counts().head(5)
genre_shares = (genre_counts / len(user_profile) * 100).round(1)
display(genre_counts)
display(genre_shares)
genre_counts.plot(kind='barh', title='Топ-5 жанров первого заказа', color='steelblue')
plt.xlabel('Число пользователей')
plt.tight_layout()
plt.show()
# Out:
# first_event_type
# концерты    9470
# другое      5527
# театр       4355
# стендап     1124
# спорт        810
# Name: count, dtype: int64
# first_event_type
# концерты    43.4
# другое      25.3
# театр       20.0
# стендап      5.2
# спорт        3.7
# Name: count, dtype: float64

# %%
device_counts = user_profile['first_device'].value_counts()
device_shares = (device_counts / len(user_profile) * 100).round(1)
display(device_counts)
display(device_shares)
device_counts.plot(kind='barh', title='Тип устройства первого заказа', color='seagreen')
plt.xlabel('Число пользователей')
plt.tight_layout()
plt.show()
# Out:
# first_device
# mobile     18014
# desktop     3707
# tablet        99
# other          1
# tv             0
# Name: count, dtype: int64
# first_device
# mobile     82.6
# desktop    17.0
# tablet      0.5
# other       0.0
# tv          0.0
# Name: count, dtype: float64

# %%
region_counts = user_profile['first_region'].value_counts().head(10)
region_shares = (region_counts / len(user_profile) * 100).round(1)
display(region_counts)
display(region_shares)
region_counts.plot(kind='barh', title='Топ-10 регионов первого заказа', color='darkorange')
plt.xlabel('Число пользователей')
plt.tight_layout()
plt.show()
# Out:
# first_region
# Каменевский регион      7249
# Североярская область    3839
# Широковская область     1252
# Озернинский край         687
# Малиновоярский округ     546
# Травяная область         499
# Светополянский округ     477
# Речиновская область      450
# Яблоневская область      419
# Медовская область        379
# Name: count, dtype: int64
# first_region
# Каменевский регион      33.2
# Североярская область    17.6
# Широковская область      5.7
# Озернинский край         3.1
# Малиновоярский округ     2.5
# Травяная область         2.3
# Светополянский округ     2.2
# Речиновская область      2.1
# Яблоневская область      1.9
# Медовская область        1.7
# Name: count, dtype: float64

# %%
service_counts = user_profile['first_service'].value_counts().head(10)
service_shares = (service_counts / len(user_profile) * 100).round(1)
display(service_counts)
display(service_shares)
service_counts.plot(kind='barh', title='Топ-10 операторов первого заказа', color='purple')
plt.xlabel('Число пользователей')
plt.tight_layout()
plt.show()
# Out:
# first_service
# Билеты без проблем    5242
# Лови билет!           2884
# Мой билет             2782
# Билеты в руки         2606
# Облачко               2216
# Весь в билетах        1326
# Лучшие билеты         1208
# Прачечная              597
# Край билетов           464
# Дом культуры           359
# Name: count, dtype: int64
# first_service
# Билеты без проблем    24.0
# Лови билет!           13.2
# Мой билет             12.7
# Билеты в руки         11.9
# Облачко               10.2
# Весь в билетах         6.1
# Лучшие билеты          5.5
# Прачечная              2.7
# Край билетов           2.1
# Дом культуры           1.6
# Name: count, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> По этом заданию отсутствуют выводы.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# По распределениям видно, что новые пользователи приходят на сервис очень неравномерно — есть явные «ворота входа».
#
# - По жанрам первый заказ чаще всего приходится на концерты — это почти половина аудитории. На втором месте — разнородная категория «другое», затем театр. Стендап, спорт и остальные жанры дают заметно меньше первых покупок.
#
# - По устройствам картина ещё более односторонняя: почти все впервые покупают с мобильного телефона, десктоп — ощутимо меньшая доля, планшеты и прочие устройства — статистический хвост.
#
# - По регионам и операторам тоже есть ярко выраженные лидеры: несколько крупных регионов и 5–6 основных билетных сервисов тянут на себе основную массу первых заказов, остальное распределено тонким слоем по множеству мелких сегментов.
#
# То есть распределение пользователей явно не равномерное: у сервиса есть несколько ключевых точек входа (концерты, мобильные устройства, крупные регионы и топ-операторы), через которые приходит основная часть новой аудитории. Остальные сегменты скорее дополняют картину, чем определяют её.

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
genre_return = (
    user_profile.groupby('first_event_type')['is_two']
    .agg(['count', 'mean'])
    .sort_values('count', ascending=False)
    .head(10))
genre_return.rename(columns={'count': 'users', 'mean': 'return_rate'}, inplace=True)
display(genre_return)
# Out:
# /tmp/ipython-input-980334517.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   user_profile.groupby('first_event_type')['is_two']
#                   users  return_rate
# first_event_type
# концерты           9470     0.621225
# другое             5527     0.600326
# театр              4355     0.641102
# стендап            1124     0.616548
# спорт               810     0.565432
# выставки            415     0.643373
# ёлки                 93     0.548387
# фильм                27     0.814815

# %%
plt.figure(figsize=(8, 4))
sns.barplot(y=genre_return.index, x=genre_return['return_rate'], orient='h', color='skyblue')
plt.xlabel('Доля возвратов (2+ заказа)')
plt.ylabel('Жанр первого мероприятия')
plt.title('Доля возвратов по жанру первого заказа')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> На графики этого типа удобнее было бы добавить `axvline` (`axhline` для устройства, так как там гистограмма вертикальная) со средним уровнем возврата по выборке для более удобного анализа точек входа.

# %% [markdown]
# Крупные сегменты — концерты (≈9300 пользователей), «другое» (≈5500), театр (≈4300) — дают устойчивые оценки. Здесь можно довольно уверенно сказать, что театр и концерты работают как хорошие входные жанры: пользователи после них чуть чаще возвращаются, чем в среднем.
#
# Выставки тоже показывают неплохую долю возвратов, но сегмент уже поменьше (≈400 пользователей).
#
# Сегменты «фильм» (27 пользователей) и «ёлки» (93 пользователя) очень небольшие. Высокая доля возврата для фильмов выглядит красиво на графике, но статистически она не значима

# %%
device_return = (
    user_profile.groupby('first_device')['is_two']
    .agg(['count', 'mean'])
    .sort_values('count', ascending=False)
)
device_return.rename(columns={'count': 'users', 'mean': 'return_rate'}, inplace=True)
display(device_return)
# Out:
# /tmp/ipython-input-3863976027.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   user_profile.groupby('first_device')['is_two']
#               users  return_rate
# first_device
# mobile        18014     0.613856
# desktop        3707     0.640140
# tablet           99     0.535354
# other             1     0.000000
# tv                0          NaN

# %% [markdown]
# Мобильные пользователи — почти ровно на уровне среднего. Это основной сегмент по объёму, поэтому именно он задаёт «общую» картину сервиса.
#
# Desktop-пользователи возвращаются чуть чаще среднего (≈64 %). Можно аккуратно считать, что для части аудитории, которая заходит с компьютера, сервис работает как немного более «цепляющая» точка входа: такие пользователи чаще приходят не один раз.
#
# Планшеты заметно ниже среднего (≈54 %), но там всего 98 пользователей, поэтому доля очень нестабильна и всерьёз на неё опираться нельзя.

# %%
plt.figure(figsize=(6, 3))
sns.barplot(
    y=device_return.index,
    x=device_return['return_rate'],
    orient='h',
    color='skyblue'
)
plt.xlabel('Доля возвратов (2+ заказа)')
plt.ylabel('Тип устройства')
plt.title('Доля возвратов по типу устройства')
plt.tight_layout()
plt.show()

# %% [markdown]
# Основная масса пользователей приходит с мобильных устройств — и они же дают наиболее высокую возвратность.
# Desktop показывает чуть более низкий уровень, но без существенной разницы.
# Tablet — редкий сегмент, статистика не показательна.

# %%
region_return = (
    user_profile.groupby('first_region')['is_two']
    .agg(users='count', return_rate='mean')
    .reset_index())
top20_by_users = (
    region_return.sort_values('users', ascending=False)
    .head(20))
top20_by_users_sorted = (
    top20_by_users.sort_values('return_rate', ascending=False))

display(top20_by_users_sorted)
# Out:
# /tmp/ipython-input-2737914158.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   user_profile.groupby('first_region')['is_two']
#                  first_region  users  return_rate
# 57       Светополянский округ    477     0.670860
# 11       Горицветская область    260     0.669231
# 77        Широковская область   1252     0.652556
# 60       Североярская область   3839     0.645220
# 52        Речиновская область    450     0.635556
# 23         Каменевский регион   7249     0.630570
# 74           Травяная область    499     0.619238
# 42          Медовская область    379     0.601583
# 76           Шанырский регион    348     0.600575
# 69       Тепляковская область    327     0.599388
# 78        Яблоневская область    419     0.599045
# ...

# %% [markdown]
# По регионам видно, что возвратность заметно отличается. Среди крупных сегментов выше среднего выглядят Каменевский регион, Североярская, Широковская и Речиновская области: доля пользователей с повторным заказом там держится на уровне 63–65% при хорошем объёме аудитории. Ещё более высокие показатели у Светополянского округа и Горицветской области (около 67%), но эти регионы уже менее массовые.
# На нижней границе выборки по возвратам находятся Глиногорская, Озернинский край, Верхоречная, Серебринская, Лугоградская область и Малиновоярский округ: у них доля возвратов — в районе 55–57%, то есть заметно ниже лидеров, но всё ещё выше половины пользователей.

# %%
top10_service_return = (
    user_profile.groupby('first_service')['is_two']
    .agg(['count', 'mean'])
    .sort_values('count', ascending=False)
    .head(10)
    .rename(columns={'count': 'users', 'mean': 'return_rate'}))
plot_df = (
    top10_service_return
    .sort_values('return_rate', ascending=False)
    .reset_index())

plt.figure(figsize=(9, 5))
sns.barplot(
    data=plot_df,
    y='first_service',
    x='return_rate',
    order=plot_df['first_service'],
    orient='h',
    color='skyblue')
plt.xlabel('Доля возвратов (2+ заказа)')
plt.ylabel('Билетный оператор')
plt.title('Доля возвратов по топ-10 билетным операторам')
plt.yticks(fontsize=9)
plt.tight_layout()
plt.show()
display(top10_service_return)
# Out:
# /tmp/ipython-input-2579819184.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   user_profile.groupby('first_service')['is_two']
#                     users  return_rate
# first_service
# Билеты без проблем   5242     0.610072
# Лови билет!          2884     0.618239
# Мой билет            2782     0.597412
# Билеты в руки        2606     0.634305
# Облачко              2216     0.620939
# Весь в билетах       1326     0.635747
# Лучшие билеты        1208     0.615894
# Прачечная             597     0.636516
# Край билетов          464     0.657328
# Дом культуры          359     0.654596

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати внимание на подпись данных на оси Y - значения наплыли друг на друга и не являются читаемыми.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Значения на графике стоит отсортировать по убыванию.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента v.2 <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# Среди крупных партнёров на уровне или выше среднего по возвратам выглядят «Лови билет!», «Облачко», «Лучшие билеты», «Билеты в руки», «Весь в билетах» и «Прачечная» (return_rate 0,62–0,64 при хорошем объёме пользователей). Чуть слабее удержание у «Билеты без проблем» и «Мой билет» (0,59–0,61), а заметно ниже среднего — у «Яблоко» (0,54). Наиболее высокие доли возвратов показывают «Край билетов», «Дом культуры», «Мир касс», Show_ticket, «Восьмёрка» и особенно «Быстрый кассир», но из-за небольшого числа пользователей это скорее точки для гипотез, чем устойчивые опорные сегменты.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты отлично справилась с интерпретацией статистической значимости. Очень важно, что ты не просто смотрела на высокие проценты возврата, но и соотносила их с количеством пользователей. Твой скепсис по поводу категории фильм или партнера Быстрый кассир абсолютно оправдан - на таких малых числах (27 и 58 человек) метрики действительно нестабильны, и ты верно это подметила.
#
# Анализ крупных сегментов проведен глубоко. Ты правильно выделила ключевые "точки входа" (театр, концерты) и основных партнеров, которые обеспечивают стабильный поток возвращающихся клиентов. Гипотеза про desktop-пользователей как более осознанную аудиторию звучит логично и подтверждается цифрами.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В задании требовалось визуализировать результаты. На скриншотах я вижу график только для типов устройств. В тексте ты упоминаешь, что "высокая доля возврата для фильмов выглядит красиво на графике", значит, сами графики у тебя скорее всего есть. Просто убедись, что в итоговой работе присутствуют визуализации для всех срезов (регионы, партнеры, типы событий), как того требовало условие.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В выводе по регионам есть фактическая ошибка в цифрах. Ты пишешь, что Шанырский регион имеет показатель возврата "менее 0,5". Однако в твоей же таблице у этого региона стоит значение 0.600575, то есть около 0,6 (или 60%). Это существенно выше половины. Более того, судя по таблице, ни один из представленных регионов не опустился ниже отметки 0,5. Проверь этот момент, чтобы выводы не противоречили данным.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %% [markdown]
# H₀: Доля пользователей, совершивших повторный заказ, среди тех, чей первый заказ был на спортивные мероприятия,
#     равна доле пользователей, совершивших повторный заказ, среди тех, чей первый заказ был на концерты.
#
# H₁: Доля пользователей, совершивших повторный заказ, среди тех, чей первый заказ был на спортивные мероприятия,
#     не равна доле пользователей, совершивших повторный заказ, среди тех, чей первый заказ был на концерты.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отлично, что не забываешь формулировать гипотезы при использовании стат.тестов.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Альтернативную гипотезу также стоит формулировать в полном виде.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Все библиотеки стоит импортировать в начале проекта - таким образом получатель твоего отчёта сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
concerts = user_profile[user_profile['first_event_type'] == 'концерты']
sport = user_profile[user_profile['first_event_type'] == 'спорт']

count = [sport['is_two'].sum(), concerts['is_two'].sum()]
nobs = [sport.shape[0], concerts.shape[0]]

stat, pval = proportions_ztest(count, nobs)
print(f'P-value: {pval:.4f}')
# Out:
# P-value: 0.0017

# %% [markdown]
# При p-value = 0.0017 мы отвергаем нулевую гипотезу: доли пользователей с повторным заказом в сегментах «спорт» и «концерты» статистически значимо различаются.
#
# С учётом оценок возврата (≈56 % для «спорта» против ≈62 % для «концертов») можно заключить, что пользователи, впервые пришедшие на «спорт», реже возвращаются, чем те, кто впервые купил билеты на концерты.

# %% [markdown]
# H₀: Доля пользователей, совершивших 2 и более заказа, среди тех, чей первый заказ был в топ-5 регионов по числу пользователей,
#     равна доле пользователей, совершивших 2 и более заказа, среди пользователей из остальных регионов.
#
# H₁: Доля пользователей, совершивших 2 и более заказа, среди тех, чей первый заказ был в топ-5 регионов по числу пользователей,
#     не равна доле пользователей, совершивших 2 и более заказа, среди пользователей из остальных регионов.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Аналогично стоит расширить альтернативную гипотезу.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
top_regions = user_profile['first_region'].value_counts().head(5).index
massive = user_profile[user_profile['first_region'].isin(top_regions)]
non_massive = user_profile[~user_profile['first_region'].isin(top_regions)]

count = [massive['is_two'].sum(), non_massive['is_two'].sum()]
nobs = [massive.shape[0], non_massive.shape[0]]

stat, pval = proportions_ztest(count, nobs)
print(f'P-value: {pval:.4e}')
# Out:
# P-value: 9.2946e-07

# %% [markdown]
# При p-value = 9.2946·10⁻⁷ мы отвергаем H₀: доля пользователей с 2+ заказами в топ-5 регионов статистически значимо отличается от доли возвратов в остальных регионах. Это значит, что структура повторных покупок в крупнейших регионах не такая же, как в остальных: поведение пользователей по возвратам там иное, и его нужно рассматривать отдельно.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Гипотезы проверены корректно.

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
one_order = user_profile[user_profile['total_orders'] == 1]
returned = user_profile[user_profile['total_orders'] >= 2]

# %%
plt.figure(figsize=(10, 5))
plt.hist(one_order['avg_revenue_rub'], bins=20, alpha=0.6, label='1 заказ', density=True, color='grey')
plt.hist(returned['avg_revenue_rub'], bins=20, alpha=0.6, label='2+ заказа', density=True, color='skyblue')
plt.xlabel('Средняя выручка с заказа, ₽')
plt.ylabel('Плотность')
plt.title('Распределение средней выручки по группам пользователей')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# По гистограмме видно, что обе группы в основном концентрируются в диапазоне до ~800 ₽ за заказ: пик плотности у «одноразовых» и у вернувшихся пользователей приходится примерно на 200–500 ₽. При этом у тех, кто делает 2+ заказа, распределение чуть смещено вправо и имеет более тяжёлый хвост: среди них заметно больше пользователей со средней выручкой от 500–1000 ₽ и выше, чем в группе с одним заказом. То есть принципиальной пропасти между группами нет, но вернувшиеся пользователи в среднем приносят более крупную выручку с заказа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты выбрала отличный способ визуализации - наложенные друг на друга гистограммы с прозрачностью. Это позволяет мгновенно сравнить две аудитории и увидеть различия в распределении.
#
# Анализ графика проведен глубоко: ты верно заметила не только смещение пика, но и "более тяжелый хвост" у вернувшихся пользователей. Вывод о том, что лояльная аудитория в среднем приносит более крупную выручку, полностью подтверждается данными на изображении.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>  В тексте вывода ты пишешь, что пик плотности у «одноразовых» пользователей приходится примерно на 200–500 ₽. Однако, судя по самому высокому серому столбцу на графике, основной пик этой группы находится в самом первом интервале - от 0 до 200 ₽ (или около того, учитывая шаг шкалы). У вернувшихся пользователей (голубой цвет) пик действительно смещен правее, в зону 200–500 ₽. Стоит быть внимательнее к границам интервалов при описании.

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
group_2_4 = user_profile[(user_profile['total_orders'] >= 2) & (user_profile['total_orders'] <= 4)]
group_5plus = user_profile[user_profile['total_orders'] >= 5]

# %%
plt.figure(figsize=(10, 5))
plt.hist(group_2_4['avg_revenue_rub'], bins=20, alpha=0.6, density=True, label='2–4 заказа', color='steelblue')
plt.hist(group_5plus['avg_revenue_rub'], bins=20, alpha=0.6, density=True, label='5+ заказов', color='salmon')
plt.xlabel('Средняя выручка с заказа, ₽')
plt.ylabel('Плотность')
plt.title('Распределение средней выручки с заказа по группам пользователей')
plt.legend()
plt.tight_layout()
plt.show()

# %%
print('2–4 заказа:')
print(group_2_4['avg_revenue_rub'].describe())

print('\n5+ заказов:')
print(group_5plus['avg_revenue_rub'].describe())
# Out:
# 2–4 заказа:
# count    7141.000000
# mean      583.732602
# std       487.277246
# min         0.000000
# 25%       228.347500
# 50%       476.225000
# 75%       817.453333
# max      3698.830000
# Name: avg_revenue_rub, dtype: float64
#
# 5+ заказов:
# count    6343.000000
# mean      559.212424
# std       327.128204
# min         0.000000
# 25%       348.641833
# 50%       523.873333
# 75%       717.001900
# max      2959.062000
# Name: avg_revenue_rub, dtype: float64

# %% [markdown]
# В обеих группах пользователи концентрируются в диапазоне примерно 300–800 ₽ за заказ, и принципиального разрыва между ними нет. У тех, кто сделал 2–4 заказа, средняя выручка чуть выше по среднему и сильнее «размазана» за счёт более дорогих заказов в хвосте (до 2 500 ₽). Группа с 5+ заказами даёт немного больший медианный чек, но распределение более компактное. В целом нельзя сказать, что пользователи с 5+ заказами существенно дороже по среднему чеку — скорее, они чаще покупают, чем тратят заметно больше за один заказ.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты очень грамотно интерпретировала разницу между средним арифметическим и медианой. Верно подмечено, что группа «2–4 заказа» имеет более высокое среднее значение только за счет длинного «хвоста» дорогих покупок, в то время как лояльная аудитория (5+) показывает более стабильный и компактный результат с высокой медианой.
#
# Итоговый бизнес-вывод сформулирован отлично: ты правильно определила, что ценность лояльных клиентов кроется не в высоком чеке разовой покупки, а в частоте их возвращения.

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
bins = [1, 2, 3, 5, np.inf]
labels = ['1-2 билета', '2-3 билета', '3-5 билетов', '5+ билетов']
user_profile['tickets_segment'] = pd.cut(user_profile['avg_tickets'], bins=bins, labels=labels, right=False)
segment_stats = (
    user_profile.groupby('tickets_segment')
    .agg(users=('user_id', 'count'), return_rate=('is_two', 'mean'))
    .reset_index())
display(segment_stats)
# Out:
# /tmp/ipython-input-2602418445.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   user_profile.groupby('tickets_segment')
#   tickets_segment  users  return_rate
# 0      1-2 билета   2432     0.512336
# 1      2-3 билета   9632     0.739099
# 2     3-5 билетов   9073     0.549432
# 3      5+ билетов    684     0.195906

# %%
plt.figure(figsize=(7, 3))
sns.barplot(
    data=segment_stats,
    x='tickets_segment',
    y='return_rate',
    color='skyblue')
plt.xlabel('Среднее количество билетов в заказе')
plt.ylabel('Доля возвратов (2+ заказа)')
plt.title('Доля возвратов по сегментам среднего количества билетов')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# %% [markdown]
# Пользователи с типичным чеком 2–3 билета заметно чаще всего возвращаются (≈74%), это самый лояльный сегмент. При средних чеках 1–2 и 3–5 билетов доля возвратов ниже (≈51–54%), а у тех, кто обычно покупает 5+ билетов, повторные заказы редки (≈19%). То есть лучше всего удерживаются «средние» по размеру покупки клиенты, а слишком маленькие и слишком большие заказы сильно уступают им по возвратам.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты правильно интерпретировала показатели возвращаемости. Вывод о том, что "средние" по размеру заказы (2–3 билета) демонстрируют самую высокую лояльность, а слишком маленькие или большие заказы уступают им - абсолютно верный и подтверждается цифрами. Все проценты в тексте соответствуют данным в таблице.

# %%
print(user_profile['avg_tickets'].describe())

plt.figure(figsize=(8, 4))
sns.histplot(user_profile['avg_tickets'], bins=30, kde=True)
plt.xlabel('Среднее количество билетов в заказе')
plt.ylabel('Число пользователей')
plt.title('Распределение среднего количества билетов на пользователя')
plt.tight_layout()
plt.show()
# Out:
# count    21821.000000
# mean         2.748974
# std          0.921211
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.111111
# max         11.000000
# Name: avg_tickets, dtype: float64

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=user_profile['avg_tickets'])
plt.xlabel('Среднее количество билетов в заказе')
plt.title('Диаграмма размаха среднего количества билетов')
plt.tight_layout()
plt.show()

# %% [markdown]
# По распределению видно, что нормальный пользователь покупает в среднем от 2 до 3 билетов за заказ. Пик приходится примерно на 2,5–3 билета: медиана — 2,75, межквартильный размах от 2 до 3,1. То есть чаще всего люди ходят на мероприятия парами или небольшой компанией.
#
# Распределение скошено вправо: есть хвост пользователей, у которых среднее количество билетов доходит до 5–6 и даже выше (максимум 11). Таких профилей немного, на боксплоте они выглядят как редкие выбросы и, скорее всего, отражают групповые или корпоративные покупки, а не ошибки в данных. В целом основная масса аудитории сосредоточена вокруг «семейно-дружеских» заказов 2–4 билета, а крупные средние чеки — редкое, но логичное для сервиса явление.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не выполнена первая часть задания `Изучите распределение пользователей по среднему количеству билетов в заказе (avg_tickets_count) и опишите основные наблюдения` - она предполагает анализ `avg_tickets_count` без учёта сегментации.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
user_profile['first_order_weekday'] = user_profile['first_order_dt'].dt.day_name()

# %%
weekday_stats = (
    user_profile.groupby('first_order_weekday')['is_two']
    .agg(['count', 'mean'])
    .reindex([
        'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
    .rename(columns={'count': 'users', 'mean': 'return_rate'}))
display(weekday_stats)
# Out:
#                      users  return_rate
# first_order_weekday
# Monday                2902     0.631978
# Tuesday               3125     0.618240
# Wednesday             3076     0.622562
# Thursday              3124     0.599872
# Friday                3287     0.602677
# Saturday              3471     0.642178
# Sunday                2836     0.606135

# %%
plt.figure(figsize=(8, 4))
sns.barplot(
    y=weekday_stats.index,
    x=weekday_stats['return_rate'],
    orient='h',
    color='skyblue')
plt.xlabel('Доля возвратов (2+ заказа)')
plt.ylabel('День недели первого заказа')
plt.title('Доля возвратов по дню недели первого заказа')
plt.tight_layout()
plt.show()

# %% [markdown]
# В среднем по базе около 62 % пользователей делают повторный заказ; на этом фоне выше всего удержание у тех, кто впервые покупал в субботу (≈64 %), а также в понедельник и середине недели (≈62–63 %). Чуть хуже возвращаются пользователи с первым заказом в четверг и пятницу (около 60 %). Разброс невелик, но можно сказать, что субботние «первые покупки» немного чаще превращаются в постоянных клиентов, а будние дни ближе к среднему уровню.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>Ты очень точно перенесла данные из таблицы в текст. Группировка дней (лидер - суббота, аутсайдеры - четверг и пятница) выполнена правильно.
#
# Особенно ценно, что ты отметила небольшой разброс значений. Разница между 60% и 64% действительно не является критической пропастью, и твой сдержанный вывод о том, что влияние дня недели невелико, абсолютно корректен.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В таблице видно, что суббота лидирует не только по проценту возвратов, но и по количеству новых пользователей (3471 - максимум за неделю). Это усиливает значимость субботы: в этот день приходит больше всего новичков, и они же лучше всего удерживаются. Стоит дополнить вывод этим наблюдением, так как это важный сигнал для бизнеса (например, для планирования рекламных бюджетов).

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
seg_2_4 = user_profile[(user_profile['total_orders'] >= 2) & (user_profile['total_orders'] <= 4)]
seg_5plus = user_profile[user_profile['total_orders'] >= 5]

print('2–4 заказа:\n', seg_2_4['avg_days_between_orders'].describe())
print('5+ заказов:\n', seg_5plus['avg_days_between_orders'].describe())
# Out:
# 2–4 заказа:
#  count    7141.000000
# mean       21.409712
# std        28.572970
# min         0.000000
# 25%         0.000000
# 50%         9.000000
# 75%        34.000000
# max       148.000000
# Name: avg_days_between_orders, dtype: float64
# 5+ заказов:
#  count    6343.000000
# mean        9.625560
# std         7.891162
# min         0.000000
# 25%         3.432432
# 50%         7.833333
# 75%        13.857143
# max        37.500000
# Name: avg_days_between_orders, dtype: float64

# %%
plt.figure(figsize=(8, 4))
plt.hist(seg_2_4['avg_days_between_orders'].dropna(), bins=20, alpha=0.6, label='2–4 заказа', density=True)
plt.hist(seg_5plus['avg_days_between_orders'].dropna(), bins=20, alpha=0.6, label='5+ заказов', density=True)
plt.xlabel('Средний интервал между заказами, дней')
plt.ylabel('Плотность')
plt.title('Распределение среднего интервала между заказами по группам пользователей')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# У пользователей с 5+ заказами средний интервал между покупками заметно короче и стабильнее: медиана около 8 дней, верхний квартиль — примерно 14 дней, максимум не превышает 37 дней. У группы с 2–4 заказами интервалы сильно растянуты: медиана около 9 дней, но среднее уезжает к 21 дню, четверть пользователей делает паузы длиннее месяца, а хвост тянется до 148 дней.
#
# То есть «тяжёлые» пользователи — это не те, кто тратит больше за раз, а те, кто ходит чаще и более регулярно. Короткий и относительно стабильный интервал между заказами напрямую связан с высоким числом покупок и лучшим удержанием, а длинные и неритмичные паузы — с меньшим числом заказов за период.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты мастерски интерпретировала статистическую выгрузку. Все цифры в тексте - медианы, квартили, средние значения и максимумы - точно перенесены из таблицы.
#
# Особенно ценно то, как ты сформулировала итоговый вывод. Мысль о том, что лояльность определяется не размером чека, а ритмичностью и стабильностью покупок - это сильный продуктовый инсайт, который прямо следует из твоих графиков и цифр. Визуализация с наложением гистограмм здесь работает отлично, наглядно показывая тот самый длинный хвост у менее лояльной аудитории.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Стоит обратить внимание на близость медианных значений: разница между 8 и 9 днями совсем небольшая. Это интересный момент, который можно было дополнительно подчеркнуть: "типичное" поведение в моменте у групп похоже, но ключевое отличие именно в дисциплине и отсутствии срывов в долгие паузы у лояльного сегмента. Это лишь подтверждает твой тезис о стабильности, добавляя ему нюансов.

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Аналогично по импортам - тут и ниже.

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
user_profile = user_profile.copy()
def segment_orders(n):
    if n == 1:
        return '1 заказ'
    elif 2 <= n <= 4:
        return '2–4 заказа'
    else:
        return '5+ заказов'
user_profile['orders_segment'] = user_profile['total_orders'].apply(segment_orders)

# %%
for col in ['first_event_type', 'first_device', 'first_region', 'first_service', 'orders_segment']:
    user_profile[col] = user_profile[col].astype('category')

# %%
user_profile['avg_days_between_orders'] = (
    user_profile['avg_days_between_orders']
    .fillna(0))

# %%
profile_cols = [
    'first_event_type', 'first_device', 'first_region', 'first_service',
    'avg_revenue_rub', 'avg_tickets', 'avg_days_between_orders', 'orders_segment']
phik_matrix = user_profile[profile_cols].phik_matrix(
    interval_cols=['avg_revenue_rub', 'avg_tickets', 'avg_days_between_orders'])

plt.figure(figsize=(8, 6))
sns.heatmap(
    phik_matrix[['orders_segment']].sort_values('orders_segment', ascending=False),
    annot=True, cmap='Blues')
plt.title('Корреляция phi_k с сегментами по числу заказов')
plt.show()

# %% [markdown]
# Корреляция с числом заказов сильнее всего у денежных и поведенческих признаков:
# лучше всего с сегментами по количеству заказов связаны средняя выручка с заказа (φₖ ≈ 0.48), среднее число билетов (≈0.41) и средний интервал между заказами (≈0.40). Чуть слабее, но заметно влияет первый регион пользователя (≈0.36). Вклад первого билетного оператора невелик (≈0.14), а жанр первого события и тип устройства первого захода почти не связаны с числом заказов (φₖ ≈ 0.04 и 0.02). То есть ключевую роль в объёме покупок играют размер и структура заказов и ритм посещений, а не особенности первого контакта по устройству или жанру.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно последовала рекомендации в задании и использовала для анализа не сырое количество заказов, а сегменты. Это позволило избежать искажений и получить адекватные коэффициенты корреляции.
#
# Выводы полностью соответствуют тепловой карте. Ты правильно ранжировала признаки по силе влияния: на первом месте действительно находятся денежные и поведенческие привычки пользователя (чек, количество билетов, ритмичность покупок), а свойства "первого касания" (устройство, жанр) играют второстепенную роль. Это важный инсайт для маркетинга: поведение пользователя после регистрации важнее того, откуда он пришел.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Есть небольшой нюанс с признаком avg_days_between_orders (средний интервал). Коэффициент корреляции с ним довольно высокий (0.4), но стоит учитывать природу данных. У сегмента пользователей с 1 заказом интервала между покупками просто не существует (или он заполнен нулем/пропуском). Получается, что корреляция здесь ловит не только связь "чем короче интервал, тем больше заказов", но и сам факт наличия повторных покупок. В выводе полезно делать на это поправку.

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# В ходе проекта мы проанализировали 292 тыс. заказов 21,7 тыс. пользователей Яндекс Афиши. Данные собраны из нескольких таблиц, дополнены лагом по времени предыдущей покупки и признаком days_since_prev. Выручка в тенге была переведена в рубли по курсу за дату заказа, затем мы удалили 381 заказ с отрицательной выручкой и обрезали «хвост» по 99-му перцентилю revenue_rub, чтобы не искажать распределение единичными крайне крупными покупками. Категориальные поля были приведены к единому виду, явных ошибок и «мусорных» значений не обнаружено.
#
# В выборке 21 676 пользователей. Медианное число заказов — 2, 75-й перцентиль — 5 заказов, при этом небольшой хвост «суперактивных» аккаунтов набирает сотни и тысячи заказов. 61,7 % пользователей сделали минимум два заказа, почти 29 % — пять и более. Средняя выручка с заказа около 540–550 ₽, типичный заказ — 2–4 билета. По интервалам между покупками медиана — около 8 дней, но разброс велик: часть аудитории покупает «сериями», часть возвращается раз в несколько месяцев.
#
# По признакам первого заказа заметны несколько вещей. Лучшие «точки входа» по жанру — театр, концерты и выставки: доля возвратов в этих сегментах 62–65 % и выше среднего. Спорт даёт более слабое удержание (≈56 %). По устройствам основной поток — мобильные (≈83 % пользователей) с возвратом на уровне среднего; пользователи, впервые купившие с десктопа, возвращаются чуть чаще (≈64 %), но эффект умеренный. Есть регионы с устойчиво высокой долей возвратов (Каменевский регион, Североярская, Широковская, Речиновская области и др.) и регионы-аутсайдеры (Малиновоярский округ, Лугоградская, Глиногорская область, Шанырский регион). Среди крупных билетных операторов лучше среднего удерживают, в том числе, «Лови билет!», «Облачко», «Билеты в руки», «Весь в билетах», «Лучшие билеты» и «Прачечная», тогда как у «Билеты без проблем», «Мой билет» и особенно «Яблоко» доля возвратов ниже.
#
# Денежные показатели и состав заказа действительно связаны с лояльностью. Пользователи с повторными покупками в среднем имеют более высокий средний чек, чем те, кто сделал только один заказ, но без радикальной разницы: главное не размер разовой траты, а поведение в динамике. Самый «здоровый» сегмент по удержанию — пользователи, покупающие в среднем 2–3 билета: среди них возвращаются около 74 %. При средних чеках 1–2 или 3–5 билетов доля возвратов падает до ~51–54 %, а пользователи, которые обычно берут 5+ билетов, почти не возвращаются (≈19 %) — это, скорее всего, разовые групповые или корпоративные покупки. Для пользователей с 5+ заказами характерны короткие и стабильные интервалы между покупками (медиана ≈8 дней, верхний квартиль ≈14 дней), тогда как в группе 2–4 заказов паузы длиннее и куда более «рваные».
#
# Временные характеристики первого заказа влияют слабо. День недели первой покупки меняет долю возвратов всего на пару процентных пунктов: немного лучше выглядят пользователи, впервые покупающие в субботу, но в целом различия невелики. Куда важнее оказывается средний интервал между заказами: чем регулярнее и чаще пользователь покупает, тем выше его вклад в общее число заказов и тем проще удерживать его дальше.
#
# Корреляционный анализ phi_k подтверждает эти выводы. Сегменты по числу заказов заметнее всего связаны со средней выручкой с заказа (φₖ ≈ 0,48), средним количеством билетов (≈0,41), средним интервалом между покупками (≈0,40) и регионом первого заказа (≈0,36). Тип первого события, первый оператор и устройство на старте дают лишь слабую связь; они могут использоваться как вспомогательные признаки, но не как ключевые драйверы поведения.
#
# **Рекомендации**
#
# - Делать основной акцент на массовом и лояльном сегменте: пользователи со средним чеком 400–900 ₽ и 2–3 билетами в заказе. Именно они чаще всего возвращаются и дают устойчивую выручку.
#
# - Для крупных покупок (5+ билетов) рассмотреть отдельный B2B-подход: групповые и корпоративные предложения, спецусловия для организаций. Не ждать от этого сегмента высокой органической повторной активности, а строить отдельный цикл продаж.
#
# - Усилить работу с жанрами-лидерами (театр, концерты, выставки) как с основными точками входа: персональные рекомендации и промо после первого заказа в этих категориях могут дать хороший эффект. Для «спортивного» сегмента стоит добавить дополнительные триггеры удержания (скидка на следующее событие, напоминания о ближайших матчах).
#
# - Использовать региональные различия. В регионах с высокой долей возвратов — углублять работу (кросс-продажи, расширение партнёров и событий), в регионах-аутсайдерах — тестировать локальные акции, улучшать ассортимент и коммуникацию с партнёрами.
#
# - В партнёрском блоке опираться на операторов с высокой долей возвратов («Лови билет!», «Облачко», «Билеты в руки», «Весь в билетах», «Лучшие билеты», «Прачечная»), а для операторов с низким удержанием проанализировать воронку и UX (как на стороне партнёра, так и на стороне Афиши).
#
# - Использовать частоту покупок как основу для триггерных кампаний: для каждого сегмента задать «нормальный» интервал между заказами и запускать напоминания и спецпредложения, когда пользователь долго не возвращается по сравнению со своей обычной активностью.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты закрыла абсолютно все пункты из задания (раздел 1.5). В выводе есть и описание предобработки данных (фильтрация, валюта, хвосты), и общая статистика по выборке, и детальный разбор по всем срезам (жанры, устройства, регионы, партнеры).
#
# Все цифры в выводе (медианный интервал 8 дней, доля возвратов 74% в сегменте 2-3 билета, корреляция 0.48 для чека) точно соответствуют тем таблицам и графикам, которые ты строила ранее. Нет никаких расхождений или взятых с потолка утверждений.
#
# Блок рекомендаций отличный. Ты не просто перечислила проблемы, а предложила конкретные решения:
#
# Выделение B2B-направления для оптовых закупок (5+ билетов) - это очень зрелое продуктовое предложение, основанное на низкой возвращаемости этого сегмента.
#
# Идея с триггерными рассылками на основе "нормального" интервала - это прямое применение твоего анализа временных рядов.
#
# Фокусировка на жанрах-лидерах как точках входа логична и обоснована данными.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Это скорее совет по оформлению, чем по аналитике. Раздел "Общий вывод" получился очень информативным, но представляет собой большую "стену текста". Чтобы заказчику было проще считывать информацию, можно использовать подзаголовки внутри текста, например: "Портрет пользователя", "Влияние характеристик первого заказа", "Корреляционный анализ". Это визуально структурирует информацию, как ты это уже сделала в блоке "Рекомендации".
#
# Также в рекомендации про триггерные кампании можно добавить конкретики из твоего анализа. Ты пишешь "задать нормальный интервал", но у тебя уже есть цифра - медиана около 8 дней и квартиль 14 дней. Можно сразу предложить: "Например, если пользователь не вернулся через 14-20 дней, отправлять пуш-уведомление".

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**

# %% [markdown]
# Ссылка на репозиторий с проектом:
# [проект](https://github.com/playlina/afisha-loyalty-analysis)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В репозитории размещены все нужные файлы.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Можно было бы также добавить `README.md` и поместить туда итоговый вывод.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Параметры подключения стоит удалить из вводной части проекта:

# %% [markdown]
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Я по-прежнему их вижу:

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Екатерина, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)
